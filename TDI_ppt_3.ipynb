# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd 
import re
from urllib.parse import urlparse
from urllib.parse import urljoin
from time import sleep
from random import randint
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
df.dtypes
# Out:
# Symbol            object
# Names             object
# Industry          object
# Prices            object
# % Change          object
# Volume            object
# Exp Ratio %       object
# 4week_return %    object
# dtype: object

# %%
df['4week_return %']=df['4week_return %'].str.replace('%','').apply(float)

# %%
df.sort_values(by='4week_return %', ascending=False)
# Out:
#    Symbol                                          Names             Industry  \
# 14   LABU      Direxion Daily S&P Biotech Bull 3x Shares        Biotechnology
# 10   ARKG        ARK Genomic Revolution Multi-Sector ETF        Biotechnology
# 24    BIB           ProShares Ultra Nasdaq Biotechnology        Biotechnology
# 19    PTH            Invesco DWA Healthcare Momentum ETF     Broad Healthcare
# 4     XBI                           SPDR S&P Biotech ETF        Biotechnology
# 23   SBIO                 ALPS Medical Breakthroughs ETF        Biotechnology
# 20    PBE     Invesco Dynamic Biotechnology & Genome ETF        Biotechnology
# 7     FBT           First Trust Amex Biotechnology Index        Biotechnology
# 2     IBB               iShares Nasdaq Biotechnology ETF        Biotechnology
# 15    BBH                     VanEck Vectors Biotech ETF        Biotechnology
# 13    XHE             SPDR S&P Health Care Equipment ETF      Medical Devices
# 9     FXH          First Trust Health Care AlphaDEX Fund     Broad Healthcare
# 22    XPH                   SPDR S&P Pharmaceuticals ETF       Pharmaceutical
# 3     IHI               iShares U.S. Medical Devices ETF      Medical Devices
# 8    FHLC            Fidelity MSCI Health Care Index ETF     Broad Healthcare
# 1     VHT                        Vanguard Healthcare ETF     Broad Healthcare
# 17    IHE               iShares U.S. Pharmaceuticals ETF       Pharmaceutical
# 18    PJP            Invesco Dynamic Pharmaceuticals ETF       Pharmaceutical
# 5     IYH                    iShares U.S. Healthcare ETF     Broad Healthcare
# 16   PSCH           Invesco S&P SmallCap Health Care ETF     Broad Healthcare
# 11    IHF          iShares U.S. Healthcare Providers ETF  Healthcare Services
# 12    RYH  Invesco S&P 500® Equal Weight Health Care ETF     Broad Healthcare
# 0     XLV            Health Care Select Sector SPDR Fund     Broad Healthcare
# 6     IXJ                  iShares Global Healthcare ETF     Broad Healthcare
# 21    PPH              VanEck Vectors Pharmaceutical ETF       Pharmaceutical
#
#      Prices % Change      Volume Exp Ratio %  4week_return %
# 14   $50.67   15.13%   3,135,624       1.12%           86.42
# 10   $46.07    6.57%     328,422       0.75%           37.40
# 24   $70.18    8.47%     209,289       0.95%           35.14
# 19  $111.89    5.96%      43,400       0.60%           25.32
# 4   $104.32    4.77%   8,031,836       0.35%           25.23
# 23   $42.13    4.28%      67,884       0.50%           22.07
# 20   $58.34    4.50%      15,105       0.57%           19.66
# 7   $163.39    3.71%     124,583       0.57%           17.48
# 2   $133.90    4.28%   3,735,500       0.47%           16.95
# 15  $158.89    4.10%      31,192       0.35%           16.63
# 13   $88.39    2.79%      52,921       0.35%           16.52
# 9    $89.52    2.64%     339,008       0.62%           14.56
# 22   $43.41    3.83%     136,781       0.35%           14.24
# 3   $267.23    1.62%     485,887       0.43%           10.29
# 8    $49.88    2.05%     404,865       0.08%            9.53
# 1   $193.06    2.01%     443,092       0.10%            9.52
# 17  $155.34    2.90%      22,849       0.42%            9.26
# 18   $64.40    2.40%      40,011       0.56%            9.26
# 5   $217.13    1.93%     123,646       0.43%            9.14
# 16  $118.27    2.06%      28,946       0.29%            9.11
# 11  $191.30    0.71%     104,014       0.43%            9.07
# 12  $217.99    1.63%      20,746       0.40%            8.81
# 0   $101.12    1.72%  15,787,099       0.13%            7.57
# 6    $68.66    1.33%     258,181       0.46%            7.43
# 21   $61.10    1.51%      94,090       0.36%            7.12

# %%
img = mpimg.imread('./LABU.png')
plt.figure(figsize =(15,15))
plt.imshow(img)

# %%
img = mpimg.imread('./PPH.png')
plt.figure(figsize =(15,15))
plt.imshow(img)
