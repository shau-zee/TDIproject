# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1['bargain_metric']= df1['52_week_low']/df1['Prices']

# %%
df1['potential_metric']= df1['52_week_high']/df1['Prices']

# %%
df1
# Out:
#                                               Names  Prices  Change % Change  \
# 0                VanEck Vectors Indonesia Index ETF   12.96    1.51  +13.20%
# 1           Invesco S&P SmallCap Low Volatility ETF   33.68    3.01   +9.80%
# 2                     SPDR EURO STOXX Small Cap ETF   45.00    3.90   +9.49%
# 3              iShares U.S. Aerospace & Defense ETF  156.97   12.40   +8.58%
# 4                  iShares MSCI India Small-Cap ETF   24.01    1.84   +8.28%
# ..                                              ...     ...     ...      ...
# 95       FlexShares US Quality Large Cap Index Fund   28.85    1.49   +5.45%
# 96           WisdomTree U.S. SmallCap Earnings Fund   22.99    1.14   +5.22%
# 97  iShares Edge MSCI Multifactor USA Small-Cap ETF   30.16    1.49   +5.20%
# 98         First Trust Small Cap Core AlphaDEX Fund   42.39    2.23   +5.54%
# 99                         Invesco S&P Spin-Off ETF   30.02    1.48   +5.19%
#
# ...

# %%
plt.hist(df1['bargain_metric'])

plt.xlabel('bargain_metric')
plt.show()

# %%
plt.hist(df1['potential_metric'])
plt.xlabel('potential_metric')

plt.show()

# %%
plt.scatter(df1['potential_metric'], df1['bargain_metric'])
plt.xlabel('potential_metric')
plt.ylabel('bargain_metric')
plt.show()

# %%
df5
# Out:
#                                                 Names  Prices  \
# 33                John Hancock Multifactor Energy ETF   10.75
# 15              Tortoise North American Pipeline Fund   14.09
# 37                            iShares U.S. Energy ETF   16.07
# 62             WisdomTree U.S. SmallCap Dividend Fund   18.47
# 17       Invesco S&P SmallCap Value with Momentum ETF   20.40
# 59                Fidelity MSCI Real Estate Index ETF   20.53
# 5             Invesco S&P 500 Equal Weight Energy ETF   21.50
# 57               SPDR Portfolio S&P 600 Small Cap ETF   22.13
# 30  First Trust Morningstar Dividend Leaders Index...   22.77
# 96             WisdomTree U.S. SmallCap Earnings Fund   22.99
# 69                          iShares MSCI Malaysia ETF   23.16
# 27  iShares U.S. Oil & Gas Exploration & Productio...   24.23
# 34             Invesco S&P Ultra Dividend Revenue ETF   24.24
# 44                 Invesco S&P 500 Enhanced Value ETF   24.62
# ...

# %%
plt.hist(df5['bargain_metric'])

plt.xlabel('bargain_metric')
plt.show()

# %%
plt.hist(df5['potential_metric'])
plt.xlabel('potential_metric')

plt.show()

# %%
plt.scatter(df5['potential_metric'], df5['bargain_metric'])
plt.xlabel('potential_metric')
plt.ylabel('bargain_metric')
plt.show()
